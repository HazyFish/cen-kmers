# %%
from pathlib import Path

import pandas as pd

# %% [markdown]
# ## Metadata

# %%
df_meta = pd.read_csv(
    Path("../GSE88907.SraRunTable.csv"),
    index_col=0
)
df_meta.head()
# Out:
#            Assay Type  AvgSpotLen       Bases   BioProject     BioSample  \
# Run
# SRR4430537   ChIP-Seq         200  2916988600  PRJNA349052  SAMN05919209
# SRR4430539   ChIP-Seq         200  3916567800  PRJNA349052  SAMN05919197
# SRR4430541   ChIP-Seq         200  3068504600  PRJNA349052  SAMN05919181
# SRR4430543   ChIP-Seq         200  7818682000  PRJNA349052  SAMN05919172
# SRR4430545   ChIP-Seq         200  8141244600  PRJNA349052  SAMN05919163
#
#                  Bytes Center Name                 chip_antibody Consent  \
# Run
# SRR4430537  1760908342         GEO  AtCENH3 (Steve Henikoff lab)  public
# SRR4430539  2372959532         GEO  AtCENH3 (Steve Henikoff lab)  public
# SRR4430541  1899661337         GEO  AtCENH3 (Steve Henikoff lab)  public
# SRR4430543  2860908696         GEO          LoCENH3 (this study)  public
# SRR4430545  2984673616         GEO          LoCENH3 (this study)  public
#
#            DATASTORE filetype  ... LibrarySelection LibrarySource  \
# ...

# %%
df_meta["chip_antibody"].value_counts()
# Out:
# chip_antibody
# AtCENH3 (Steve Henikoff lab)    3
# LoCENH3 (this study)            3
# ZmCENH3 (Kelly Dawe lab)        3
# none                            2
# Name: count, dtype: int64

# %%
df_meta_filtered = df_meta[df_meta["chip_antibody"].isin(["AtCENH3 (Steve Henikoff lab)", "none"])]
df_meta_filtered
# Out:
#            Assay Type  AvgSpotLen       Bases   BioProject     BioSample  \
# Run
# SRR4430537   ChIP-Seq         200  2916988600  PRJNA349052  SAMN05919209
# SRR4430539   ChIP-Seq         200  3916567800  PRJNA349052  SAMN05919197
# SRR4430541   ChIP-Seq         200  3068504600  PRJNA349052  SAMN05919181
# SRR4430555   ChIP-Seq         200  3819348200  PRJNA349052  SAMN05919072
# SRR4430557   ChIP-Seq         200  7390176000  PRJNA349052  SAMN05919056
#
#                  Bytes Center Name                 chip_antibody Consent  \
# Run
# SRR4430537  1760908342         GEO  AtCENH3 (Steve Henikoff lab)  public
# SRR4430539  2372959532         GEO  AtCENH3 (Steve Henikoff lab)  public
# SRR4430541  1899661337         GEO  AtCENH3 (Steve Henikoff lab)  public
# SRR4430555  2274409380         GEO                          none  public
# SRR4430557  2797303390         GEO                          none  public
#
#            DATASTORE filetype  ... LibrarySelection LibrarySource  \
# ...
